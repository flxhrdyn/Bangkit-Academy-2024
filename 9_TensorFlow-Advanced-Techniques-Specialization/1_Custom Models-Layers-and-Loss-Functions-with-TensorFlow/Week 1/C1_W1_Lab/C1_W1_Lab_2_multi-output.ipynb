# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 217.3974 - y1_output_loss: 101.1598 - y2_output_loss: 114.6128 - y1_output_root_mean_squared_error: 10.1003 - y2_output_root_mean_squared_error: 10.7415 - val_loss: 66.4959 - val_y1_output_loss: 24.6430 - val_y2_output_loss: 42.9088 - val_y1_output_root_mean_squared_error: 4.8805 - val_y2_output_root_mean_squared_error: 6.5328
# Epoch 2/500
# 614/614 [==============================] - 0s 178us/sample - loss: 35.7341 - y1_output_loss: 13.0386 - y2_output_loss: 22.3718 - y1_output_root_mean_squared_error: 3.6276 - y2_output_root_mean_squared_error: 4.7513 - val_loss: 24.1056 - val_y1_output_loss: 11.3325 - val_y2_output_loss: 12.9666 - val_y1_output_root_mean_squared_error: 3.3230 - val_y2_output_root_mean_squared_error: 3.6143
# Epoch 3/500
# 614/614 [==============================] - 0s 157us/sample - loss: 25.2403 - y1_output_loss: 10.1338 - y2_output_loss: 15.1308 - y1_output_root_mean_squared_error: 3.1921 - y2_output_root_mean_squared_error: 3.8795 - val_loss: 52.1679 - val_y1_output_loss: 14.2143 - val_y2_output_loss: 38.5598 - val_y1_output_root_mean_squared_error: 3.7497 - val_y2_output_root_mean_squared_error: 6.1732
# Epoch 4/500
# 614/614 [==============================] - 0s 184us/sample - loss: 24.7046 - y1_output_loss: 9.2229 - y2_output_loss: 15.2947 - y1_output_root_mean_squared_error: 3.0491 - y2_output_root_mean_squared_error: 3.9252 - val_loss: 21.0380 - val_y1_output_loss: 9.7813 - val_y2_output_loss: 11.2126 - val_y1_output_root_mean_squared_error: 3.0948 - val_y2_output_root_mean_squared_error: 3.3853
# Epoch 5/500
# 614/614 [==============================] - 0s 175us/sample - loss: 25.3517 - y1_output_loss: 9.9099 - y2_output_loss: 15.2588 - y1_output_root_mean_squared_error: 3.1612 - y2_output_root_mean_squared_error: 3.9190 - val_loss: 19.4028 - val_y1_output_loss: 9.3127 - val_y2_output_loss: 10.3205 - val_y1_output_root_mean_squared_error: 2.9808 - val_y2_output_root_mean_squared_error: 3.2431
# Epoch 6/500
# 614/614 [==============================] - 0s 173us/sample - loss: 28.2659 - y1_output_loss: 9.7764 - y2_output_loss: 18.4461 - y1_output_root_mean_squared_error: 3.1217 - y2_output_root_mean_squared_error: 4.3036 - val_loss: 23.6973 - val_y1_output_loss: 9.0907 - val_y2_output_loss: 15.0662 - val_y1_output_root_mean_squared_error: 2.9516 - val_y2_output_root_mean_squared_error: 3.8711
# Epoch 7/500
# 614/614 [==============================] - 0s 173us/sample - loss: 24.9586 - y1_output_loss: 9.5616 - y2_output_loss: 15.3520 - y1_output_root_mean_squared_error: 3.0868 - y2_output_root_mean_squared_error: 3.9281 - val_loss: 20.3557 - val_y1_output_loss: 8.9280 - val_y2_output_loss: 11.5414 - val_y1_output_root_mean_squared_error: 2.9401 - val_y2_output_root_mean_squared_error: 3.4222
# Epoch 8/500
# 614/614 [==============================] - 0s 155us/sample - loss: 23.3486 - y1_output_loss: 8.8229 - y2_output_loss: 14.5332 - y1_output_root_mean_squared_error: 2.9686 - y2_output_root_mean_squared_error: 3.8126 - val_loss: 24.7433 - val_y1_output_loss: 8.6635 - val_y2_output_loss: 16.3313 - val_y1_output_root_mean_squared_error: 2.9110 - val_y2_output_root_mean_squared_error: 4.0335
# Epoch 9/500
# 614/614 [==============================] - 0s 163us/sample - loss: 24.4087 - y1_output_loss: 9.2318 - y2_output_loss: 15.0586 - y1_output_root_mean_squared_error: 3.0452 - y2_output_root_mean_squared_error: 3.8904 - val_loss: 18.2392 - val_y1_output_loss: 8.1875 - val_y2_output_loss: 10.0148 - val_y1_output_root_mean_squared_error: 2.8259 - val_y2_output_root_mean_squared_error: 3.2021
# Epoch 10/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.0519 - y1_output_loss: 8.5088 - y2_output_loss: 14.3877 - y1_output_root_mean_squared_error: 2.9218 - y2_output_root_mean_squared_error: 3.8098 - val_loss: 18.1777 - val_y1_output_loss: 8.5482 - val_y2_output_loss: 9.6643 - val_y1_output_root_mean_squared_error: 2.8923 - val_y2_output_root_mean_squared_error: 3.1324
# Epoch 11/500
# 614/614 [==============================] - 0s 160us/sample - loss: 21.9881 - y1_output_loss: 8.3110 - y2_output_loss: 13.6094 - y1_output_root_mean_squared_error: 2.8852 - y2_output_root_mean_squared_error: 3.6964 - val_loss: 24.0759 - val_y1_output_loss: 9.2656 - val_y2_output_loss: 15.1262 - val_y1_output_root_mean_squared_error: 2.9768 - val_y2_output_root_mean_squared_error: 3.9006
# Epoch 12/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.5002 - y1_output_loss: 8.0269 - y2_output_loss: 14.4747 - y1_output_root_mean_squared_error: 2.8456 - y2_output_root_mean_squared_error: 3.7951 - val_loss: 45.5650 - val_y1_output_loss: 14.1078 - val_y2_output_loss: 31.9848 - val_y1_output_root_mean_squared_error: 3.6891 - val_y2_output_root_mean_squared_error: 5.6529
# Epoch 13/500
# 614/614 [==============================] - 0s 166us/sample - loss: 23.1251 - y1_output_loss: 8.0423 - y2_output_loss: 15.1291 - y1_output_root_mean_squared_error: 2.8385 - y2_output_root_mean_squared_error: 3.8817 - val_loss: 40.3792 - val_y1_output_loss: 11.7464 - val_y2_output_loss: 28.5708 - val_y1_output_root_mean_squared_error: 3.4524 - val_y2_output_root_mean_squared_error: 5.3348
# Epoch 14/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.4281 - y1_output_loss: 7.7186 - y2_output_loss: 12.5620 - y1_output_root_mean_squared_error: 2.7888 - y2_output_root_mean_squared_error: 3.5568 - val_loss: 17.6150 - val_y1_output_loss: 7.7802 - val_y2_output_loss: 9.6003 - val_y1_output_root_mean_squared_error: 2.7895 - val_y2_output_root_mean_squared_error: 3.1359
# Epoch 15/500
# 614/614 [==============================] - 0s 176us/sample - loss: 20.6299 - y1_output_loss: 7.8415 - y2_output_loss: 12.7305 - y1_output_root_mean_squared_error: 2.7940 - y2_output_root_mean_squared_error: 3.5810 - val_loss: 17.8735 - val_y1_output_loss: 7.7462 - val_y2_output_loss: 10.2548 - val_y1_output_root_mean_squared_error: 2.7362 - val_y2_output_root_mean_squared_error: 3.2229
# Epoch 16/500
# 614/614 [==============================] - 0s 149us/sample - loss: 20.6959 - y1_output_loss: 7.6124 - y2_output_loss: 12.9167 - y1_output_root_mean_squared_error: 2.7714 - y2_output_root_mean_squared_error: 3.6077 - val_loss: 16.5655 - val_y1_output_loss: 7.4047 - val_y2_output_loss: 9.0453 - val_y1_output_root_mean_squared_error: 2.7167 - val_y2_output_root_mean_squared_error: 3.0307
# Epoch 17/500
# 614/614 [==============================] - 0s 151us/sample - loss: 20.5280 - y1_output_loss: 7.7023 - y2_output_loss: 12.8557 - y1_output_root_mean_squared_error: 2.7684 - y2_output_root_mean_squared_error: 3.5866 - val_loss: 24.0166 - val_y1_output_loss: 11.8438 - val_y2_output_loss: 13.1131 - val_y1_output_root_mean_squared_error: 3.3313 - val_y2_output_root_mean_squared_error: 3.5943
# Epoch 18/500
# 614/614 [==============================] - 0s 156us/sample - loss: 18.0379 - y1_output_loss: 7.2289 - y2_output_loss: 10.8989 - y1_output_root_mean_squared_error: 2.6931 - y2_output_root_mean_squared_error: 3.2841 - val_loss: 30.0159 - val_y1_output_loss: 9.0621 - val_y2_output_loss: 21.0075 - val_y1_output_root_mean_squared_error: 3.0158 - val_y2_output_root_mean_squared_error: 4.5740
# Epoch 19/500
# 614/614 [==============================] - 0s 157us/sample - loss: 18.9848 - y1_output_loss: 7.2170 - y2_output_loss: 11.6380 - y1_output_root_mean_squared_error: 2.6955 - y2_output_root_mean_squared_error: 3.4233 - val_loss: 14.0345 - val_y1_output_loss: 6.6496 - val_y2_output_loss: 7.5857 - val_y1_output_root_mean_squared_error: 2.5222 - val_y2_output_root_mean_squared_error: 2.7700
# Epoch 20/500
# 614/614 [==============================] - 0s 168us/sample - loss: 17.2873 - y1_output_loss: 6.7150 - y2_output_loss: 10.7062 - y1_output_root_mean_squared_error: 2.5938 - y2_output_root_mean_squared_error: 3.2496 - val_loss: 33.8421 - val_y1_output_loss: 12.2469 - val_y2_output_loss: 21.6226 - val_y1_output_root_mean_squared_error: 3.5229 - val_y2_output_root_mean_squared_error: 4.6294
# Epoch 21/500
# 614/614 [==============================] - 0s 163us/sample - loss: 19.2404 - y1_output_loss: 7.2161 - y2_output_loss: 11.9146 - y1_output_root_mean_squared_error: 2.6951 - y2_output_root_mean_squared_error: 3.4608 - val_loss: 21.3191 - val_y1_output_loss: 7.8414 - val_y2_output_loss: 13.4669 - val_y1_output_root_mean_squared_error: 2.8122 - val_y2_output_root_mean_squared_error: 3.6621
# Epoch 22/500
# 614/614 [==============================] - 0s 162us/sample - loss: 18.0407 - y1_output_loss: 6.7797 - y2_output_loss: 11.4090 - y1_output_root_mean_squared_error: 2.5904 - y2_output_root_mean_squared_error: 3.3661 - val_loss: 23.0763 - val_y1_output_loss: 6.6835 - val_y2_output_loss: 16.2459 - val_y1_output_root_mean_squared_error: 2.6047 - val_y2_output_root_mean_squared_error: 4.0363
# Epoch 23/500
# 614/614 [==============================] - 0s 152us/sample - loss: 17.0623 - y1_output_loss: 6.3770 - y2_output_loss: 10.6303 - y1_output_root_mean_squared_error: 2.5286 - y2_output_root_mean_squared_error: 3.2663 - val_loss: 20.5727 - val_y1_output_loss: 8.3162 - val_y2_output_loss: 12.1943 - val_y1_output_root_mean_squared_error: 2.8593 - val_y2_output_root_mean_squared_error: 3.5210
# Epoch 24/500
# 614/614 [==============================] - 0s 163us/sample - loss: 14.9905 - y1_output_loss: 5.8906 - y2_output_loss: 9.0009 - y1_output_root_mean_squared_error: 2.4353 - y2_output_root_mean_squared_error: 3.0100 - val_loss: 12.4530 - val_y1_output_loss: 5.3107 - val_y2_output_loss: 7.0902 - val_y1_output_root_mean_squared_error: 2.2790 - val_y2_output_root_mean_squared_error: 2.6943
# Epoch 25/500
# 614/614 [==============================] - 0s 151us/sample - loss: 17.6647 - y1_output_loss: 6.1325 - y2_output_loss: 11.4131 - y1_output_root_mean_squared_error: 2.4799 - y2_output_root_mean_squared_error: 3.3933 - val_loss: 16.1448 - val_y1_output_loss: 6.1859 - val_y2_output_loss: 10.2180 - val_y1_output_root_mean_squared_error: 2.4307 - val_y2_output_root_mean_squared_error: 3.1995
# Epoch 26/500
# 614/614 [==============================] - 0s 186us/sample - loss: 14.2181 - y1_output_loss: 5.5195 - y2_output_loss: 8.6298 - y1_output_root_mean_squared_error: 2.3526 - y2_output_root_mean_squared_error: 2.9468 - val_loss: 14.2915 - val_y1_output_loss: 6.1981 - val_y2_output_loss: 7.9326 - val_y1_output_root_mean_squared_error: 2.4920 - val_y2_output_root_mean_squared_error: 2.8428
# Epoch 27/500
# 614/614 [==============================] - 0s 173us/sample - loss: 14.6845 - y1_output_loss: 5.2921 - y2_output_loss: 9.4623 - y1_output_root_mean_squared_error: 2.3007 - y2_output_root_mean_squared_error: 3.0645 - val_loss: 24.5999 - val_y1_output_loss: 8.4225 - val_y2_output_loss: 16.7540 - val_y1_output_root_mean_squared_error: 2.8224 - val_y2_output_root_mean_squared_error: 4.0785
# Epoch 28/500
# 614/614 [==============================] - 0s 170us/sample - loss: 12.9003 - y1_output_loss: 4.6867 - y2_output_loss: 8.1732 - y1_output_root_mean_squared_error: 2.1702 - y2_output_root_mean_squared_error: 2.8619 - val_loss: 20.7055 - val_y1_output_loss: 6.1021 - val_y2_output_loss: 14.5706 - val_y1_output_root_mean_squared_error: 2.4824 - val_y2_output_root_mean_squared_error: 3.8136
# Epoch 29/500
# 614/614 [==============================] - 0s 171us/sample - loss: 15.4141 - y1_output_loss: 5.5615 - y2_output_loss: 9.7089 - y1_output_root_mean_squared_error: 2.3694 - y2_output_root_mean_squared_error: 3.1305 - val_loss: 10.2880 - val_y1_output_loss: 3.6178 - val_y2_output_loss: 6.5926 - val_y1_output_root_mean_squared_error: 1.8918 - val_y2_output_root_mean_squared_error: 2.5902
# Epoch 30/500
# 614/614 [==============================] - 0s 150us/sample - loss: 13.0572 - y1_output_loss: 4.7112 - y2_output_loss: 8.3563 - y1_output_root_mean_squared_error: 2.1659 - y2_output_root_mean_squared_error: 2.8924 - val_loss: 10.1399 - val_y1_output_loss: 4.0230 - val_y2_output_loss: 6.0685 - val_y1_output_root_mean_squared_error: 2.0043 - val_y2_output_root_mean_squared_error: 2.4744
# Epoch 31/500
# 614/614 [==============================] - 0s 165us/sample - loss: 11.1023 - y1_output_loss: 4.0907 - y2_output_loss: 7.0181 - y1_output_root_mean_squared_error: 2.0298 - y2_output_root_mean_squared_error: 2.6424 - val_loss: 12.3514 - val_y1_output_loss: 4.0114 - val_y2_output_loss: 8.3446 - val_y1_output_root_mean_squared_error: 2.0062 - val_y2_output_root_mean_squared_error: 2.8856
# Epoch 32/500
# 614/614 [==============================] - 0s 156us/sample - loss: 11.3180 - y1_output_loss: 4.0982 - y2_output_loss: 7.1275 - y1_output_root_mean_squared_error: 2.0335 - y2_output_root_mean_squared_error: 2.6801 - val_loss: 7.7976 - val_y1_output_loss: 3.0074 - val_y2_output_loss: 4.7547 - val_y1_output_root_mean_squared_error: 1.7169 - val_y2_output_root_mean_squared_error: 2.2023
# Epoch 33/500
# 614/614 [==============================] - 0s 178us/sample - loss: 11.3183 - y1_output_loss: 3.9292 - y2_output_loss: 7.3774 - y1_output_root_mean_squared_error: 1.9854 - y2_output_root_mean_squared_error: 2.7159 - val_loss: 8.5438 - val_y1_output_loss: 2.8684 - val_y2_output_loss: 5.6330 - val_y1_output_root_mean_squared_error: 1.6779 - val_y2_output_root_mean_squared_error: 2.3934
# Epoch 34/500
# 614/614 [==============================] - 0s 175us/sample - loss: 10.7723 - y1_output_loss: 3.9590 - y2_output_loss: 6.8351 - y1_output_root_mean_squared_error: 1.9839 - y2_output_root_mean_squared_error: 2.6147 - val_loss: 21.2357 - val_y1_output_loss: 7.4778 - val_y2_output_loss: 13.8476 - val_y1_output_root_mean_squared_error: 2.6921 - val_y2_output_root_mean_squared_error: 3.7401
# Epoch 35/500
# 614/614 [==============================] - 0s 167us/sample - loss: 11.0594 - y1_output_loss: 3.9013 - y2_output_loss: 7.0801 - y1_output_root_mean_squared_error: 1.9830 - y2_output_root_mean_squared_error: 2.6696 - val_loss: 8.8974 - val_y1_output_loss: 3.0572 - val_y2_output_loss: 5.7980 - val_y1_output_root_mean_squared_error: 1.7405 - val_y2_output_root_mean_squared_error: 2.4224
# Epoch 36/500
# 614/614 [==============================] - 0s 165us/sample - loss: 8.7188 - y1_output_loss: 3.0715 - y2_output_loss: 5.6466 - y1_output_root_mean_squared_error: 1.7586 - y2_output_root_mean_squared_error: 2.3720 - val_loss: 7.8695 - val_y1_output_loss: 2.8642 - val_y2_output_loss: 4.9660 - val_y1_output_root_mean_squared_error: 1.6801 - val_y2_output_root_mean_squared_error: 2.2465
# Epoch 37/500
# 614/614 [==============================] - 0s 175us/sample - loss: 8.8047 - y1_output_loss: 3.1692 - y2_output_loss: 6.0746 - y1_output_root_mean_squared_error: 1.7474 - y2_output_root_mean_squared_error: 2.3982 - val_loss: 108.8984 - val_y1_output_loss: 29.3820 - val_y2_output_loss: 81.1152 - val_y1_output_root_mean_squared_error: 5.3395 - val_y2_output_root_mean_squared_error: 8.9659
# Epoch 38/500
# 614/614 [==============================] - 0s 162us/sample - loss: 10.3940 - y1_output_loss: 3.6848 - y2_output_loss: 6.8571 - y1_output_root_mean_squared_error: 1.9077 - y2_output_root_mean_squared_error: 2.5990 - val_loss: 8.5475 - val_y1_output_loss: 3.0825 - val_y2_output_loss: 5.4161 - val_y1_output_root_mean_squared_error: 1.7374 - val_y2_output_root_mean_squared_error: 2.3514
# Epoch 39/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.1290 - y1_output_loss: 3.1361 - y2_output_loss: 5.9758 - y1_output_root_mean_squared_error: 1.7766 - y2_output_root_mean_squared_error: 2.4440 - val_loss: 20.0748 - val_y1_output_loss: 4.5650 - val_y2_output_loss: 16.0212 - val_y1_output_root_mean_squared_error: 2.1538 - val_y2_output_root_mean_squared_error: 3.9289
# Epoch 40/500
# 614/614 [==============================] - 0s 157us/sample - loss: 7.4848 - y1_output_loss: 2.7587 - y2_output_loss: 4.6768 - y1_output_root_mean_squared_error: 1.6628 - y2_output_root_mean_squared_error: 2.1726 - val_loss: 7.2984 - val_y1_output_loss: 2.0655 - val_y2_output_loss: 5.3004 - val_y1_output_root_mean_squared_error: 1.4295 - val_y2_output_root_mean_squared_error: 2.2924
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.4175 - y1_output_loss: 2.5722 - y2_output_loss: 5.1429 - y1_output_root_mean_squared_error: 1.5753 - y2_output_root_mean_squared_error: 2.2217 - val_loss: 18.0984 - val_y1_output_loss: 6.4818 - val_y2_output_loss: 12.4424 - val_y1_output_root_mean_squared_error: 2.4847 - val_y2_output_root_mean_squared_error: 3.4532
# Epoch 42/500
# 614/614 [==============================] - 0s 160us/sample - loss: 9.3341 - y1_output_loss: 2.9998 - y2_output_loss: 6.2566 - y1_output_root_mean_squared_error: 1.7383 - y2_output_root_mean_squared_error: 2.5125 - val_loss: 6.0220 - val_y1_output_loss: 1.6950 - val_y2_output_loss: 4.2757 - val_y1_output_root_mean_squared_error: 1.3084 - val_y2_output_root_mean_squared_error: 2.0761
# Epoch 43/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.8652 - y1_output_loss: 2.4353 - y2_output_loss: 4.3838 - y1_output_root_mean_squared_error: 1.5637 - y2_output_root_mean_squared_error: 2.1024 - val_loss: 6.1659 - val_y1_output_loss: 1.7939 - val_y2_output_loss: 4.3434 - val_y1_output_root_mean_squared_error: 1.3477 - val_y2_output_root_mean_squared_error: 2.0856
# Epoch 44/500
# 614/614 [==============================] - 0s 175us/sample - loss: 7.9056 - y1_output_loss: 2.6072 - y2_output_loss: 5.2854 - y1_output_root_mean_squared_error: 1.6181 - y2_output_root_mean_squared_error: 2.2994 - val_loss: 9.4568 - val_y1_output_loss: 2.6036 - val_y2_output_loss: 6.8021 - val_y1_output_root_mean_squared_error: 1.5922 - val_y2_output_root_mean_squared_error: 2.6309
# Epoch 45/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.9394 - y1_output_loss: 2.0938 - y2_output_loss: 4.8293 - y1_output_root_mean_squared_error: 1.4528 - y2_output_root_mean_squared_error: 2.1975 - val_loss: 14.3147 - val_y1_output_loss: 3.0875 - val_y2_output_loss: 11.6101 - val_y1_output_root_mean_squared_error: 1.7651 - val_y2_output_root_mean_squared_error: 3.3465
# Epoch 46/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.5276 - y1_output_loss: 2.4140 - y2_output_loss: 5.0862 - y1_output_root_mean_squared_error: 1.5474 - y2_output_root_mean_squared_error: 2.2657 - val_loss: 5.8728 - val_y1_output_loss: 1.7858 - val_y2_output_loss: 4.1141 - val_y1_output_root_mean_squared_error: 1.3285 - val_y2_output_root_mean_squared_error: 2.0268
# Epoch 47/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.7180 - y1_output_loss: 2.0195 - y2_output_loss: 4.6755 - y1_output_root_mean_squared_error: 1.4158 - y2_output_root_mean_squared_error: 2.1711 - val_loss: 6.0628 - val_y1_output_loss: 1.8426 - val_y2_output_loss: 4.1451 - val_y1_output_root_mean_squared_error: 1.3649 - val_y2_output_root_mean_squared_error: 2.0494
# Epoch 48/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.0268 - y1_output_loss: 2.2721 - y2_output_loss: 4.7052 - y1_output_root_mean_squared_error: 1.5123 - y2_output_root_mean_squared_error: 2.1771 - val_loss: 9.6663 - val_y1_output_loss: 3.2434 - val_y2_output_loss: 6.4473 - val_y1_output_root_mean_squared_error: 1.7833 - val_y2_output_root_mean_squared_error: 2.5468
# Epoch 49/500
# 614/614 [==============================] - 0s 160us/sample - loss: 6.2499 - y1_output_loss: 1.9809 - y2_output_loss: 4.2321 - y1_output_root_mean_squared_error: 1.4083 - y2_output_root_mean_squared_error: 2.0655 - val_loss: 5.1078 - val_y1_output_loss: 1.4420 - val_y2_output_loss: 3.6492 - val_y1_output_root_mean_squared_error: 1.2061 - val_y2_output_root_mean_squared_error: 1.9113
# Epoch 50/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.4217 - y1_output_loss: 1.7434 - y2_output_loss: 3.6365 - y1_output_root_mean_squared_error: 1.3258 - y2_output_root_mean_squared_error: 1.9142 - val_loss: 5.7505 - val_y1_output_loss: 1.4756 - val_y2_output_loss: 4.2761 - val_y1_output_root_mean_squared_error: 1.2234 - val_y2_output_root_mean_squared_error: 2.0625
# Epoch 51/500
# 614/614 [==============================] - 0s 182us/sample - loss: 9.1040 - y1_output_loss: 2.6119 - y2_output_loss: 6.4362 - y1_output_root_mean_squared_error: 1.6221 - y2_output_root_mean_squared_error: 2.5442 - val_loss: 7.6810 - val_y1_output_loss: 2.0480 - val_y2_output_loss: 5.5610 - val_y1_output_root_mean_squared_error: 1.4277 - val_y2_output_root_mean_squared_error: 2.3754
# Epoch 52/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.6402 - y1_output_loss: 1.7367 - y2_output_loss: 4.0071 - y1_output_root_mean_squared_error: 1.3144 - y2_output_root_mean_squared_error: 1.9780 - val_loss: 6.8842 - val_y1_output_loss: 2.8257 - val_y2_output_loss: 3.9710 - val_y1_output_root_mean_squared_error: 1.7005 - val_y2_output_root_mean_squared_error: 1.9981
# Epoch 53/500
# 614/614 [==============================] - 0s 157us/sample - loss: 7.8095 - y1_output_loss: 2.4105 - y2_output_loss: 5.4721 - y1_output_root_mean_squared_error: 1.5451 - y2_output_root_mean_squared_error: 2.3285 - val_loss: 10.5540 - val_y1_output_loss: 2.4176 - val_y2_output_loss: 8.2108 - val_y1_output_root_mean_squared_error: 1.5201 - val_y2_output_root_mean_squared_error: 2.8711
# Epoch 54/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.0871 - y1_output_loss: 1.8681 - y2_output_loss: 4.1816 - y1_output_root_mean_squared_error: 1.3711 - y2_output_root_mean_squared_error: 2.0511 - val_loss: 5.3481 - val_y1_output_loss: 1.2706 - val_y2_output_loss: 4.1217 - val_y1_output_root_mean_squared_error: 1.1320 - val_y2_output_root_mean_squared_error: 2.0166
# Epoch 55/500
# 614/614 [==============================] - 0s 176us/sample - loss: 5.4012 - y1_output_loss: 1.5900 - y2_output_loss: 3.8175 - y1_output_root_mean_squared_error: 1.2620 - y2_output_root_mean_squared_error: 1.9515 - val_loss: 10.5658 - val_y1_output_loss: 2.5101 - val_y2_output_loss: 8.0209 - val_y1_output_root_mean_squared_error: 1.5674 - val_y2_output_root_mean_squared_error: 2.8476
# Epoch 56/500
# 614/614 [==============================] - 0s 173us/sample - loss: 5.1710 - y1_output_loss: 1.4450 - y2_output_loss: 3.7253 - y1_output_root_mean_squared_error: 1.2051 - y2_output_root_mean_squared_error: 1.9284 - val_loss: 9.8769 - val_y1_output_loss: 1.4618 - val_y2_output_loss: 8.3378 - val_y1_output_root_mean_squared_error: 1.2029 - val_y2_output_root_mean_squared_error: 2.9034
# Epoch 57/500
# 614/614 [==============================] - 0s 168us/sample - loss: 6.4888 - y1_output_loss: 1.9428 - y2_output_loss: 4.5729 - y1_output_root_mean_squared_error: 1.3852 - y2_output_root_mean_squared_error: 2.1378 - val_loss: 4.8435 - val_y1_output_loss: 1.1015 - val_y2_output_loss: 3.8017 - val_y1_output_root_mean_squared_error: 1.0533 - val_y2_output_root_mean_squared_error: 1.9324
# Epoch 58/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.2922 - y1_output_loss: 1.7686 - y2_output_loss: 4.5176 - y1_output_root_mean_squared_error: 1.3348 - y2_output_root_mean_squared_error: 2.1238 - val_loss: 4.8183 - val_y1_output_loss: 1.1864 - val_y2_output_loss: 3.6457 - val_y1_output_root_mean_squared_error: 1.0885 - val_y2_output_root_mean_squared_error: 1.9062
# Epoch 59/500
# 614/614 [==============================] - 0s 174us/sample - loss: 5.6560 - y1_output_loss: 1.5892 - y2_output_loss: 4.0138 - y1_output_root_mean_squared_error: 1.2665 - y2_output_root_mean_squared_error: 2.0129 - val_loss: 4.6258 - val_y1_output_loss: 1.1009 - val_y2_output_loss: 3.5652 - val_y1_output_root_mean_squared_error: 1.0461 - val_y2_output_root_mean_squared_error: 1.8792
# Epoch 60/500
# 614/614 [==============================] - 0s 170us/sample - loss: 5.7736 - y1_output_loss: 1.6187 - y2_output_loss: 4.3573 - y1_output_root_mean_squared_error: 1.2609 - y2_output_root_mean_squared_error: 2.0454 - val_loss: 23.7005 - val_y1_output_loss: 4.7770 - val_y2_output_loss: 19.9574 - val_y1_output_root_mean_squared_error: 2.1737 - val_y2_output_root_mean_squared_error: 4.3561
# Epoch 61/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.5392 - y1_output_loss: 1.5806 - y2_output_loss: 3.9414 - y1_output_root_mean_squared_error: 1.2563 - y2_output_root_mean_squared_error: 1.9902 - val_loss: 7.5388 - val_y1_output_loss: 2.2957 - val_y2_output_loss: 5.4220 - val_y1_output_root_mean_squared_error: 1.5024 - val_y2_output_root_mean_squared_error: 2.2982
# Epoch 62/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.4331 - y1_output_loss: 1.6213 - y2_output_loss: 3.8333 - y1_output_root_mean_squared_error: 1.2634 - y2_output_root_mean_squared_error: 1.9588 - val_loss: 8.0571 - val_y1_output_loss: 2.1511 - val_y2_output_loss: 5.9426 - val_y1_output_root_mean_squared_error: 1.4569 - val_y2_output_root_mean_squared_error: 2.4361
# Epoch 63/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.6747 - y1_output_loss: 1.3310 - y2_output_loss: 3.3356 - y1_output_root_mean_squared_error: 1.1578 - y2_output_root_mean_squared_error: 1.8260 - val_loss: 6.0163 - val_y1_output_loss: 1.5618 - val_y2_output_loss: 4.5860 - val_y1_output_root_mean_squared_error: 1.2507 - val_y2_output_root_mean_squared_error: 2.1100
# Epoch 64/500
# 614/614 [==============================] - 0s 179us/sample - loss: 5.3800 - y1_output_loss: 1.6806 - y2_output_loss: 3.6954 - y1_output_root_mean_squared_error: 1.2972 - y2_output_root_mean_squared_error: 1.9228 - val_loss: 7.0784 - val_y1_output_loss: 1.9875 - val_y2_output_loss: 5.2725 - val_y1_output_root_mean_squared_error: 1.4199 - val_y2_output_root_mean_squared_error: 2.2500
# Epoch 65/500
# 614/614 [==============================] - 0s 165us/sample - loss: 5.9684 - y1_output_loss: 1.7157 - y2_output_loss: 4.2179 - y1_output_root_mean_squared_error: 1.3096 - y2_output_root_mean_squared_error: 2.0623 - val_loss: 5.5401 - val_y1_output_loss: 1.2493 - val_y2_output_loss: 4.2724 - val_y1_output_root_mean_squared_error: 1.1076 - val_y2_output_root_mean_squared_error: 2.0769
# Epoch 66/500
# 614/614 [==============================] - 0s 168us/sample - loss: 8.4263 - y1_output_loss: 2.4957 - y2_output_loss: 5.9124 - y1_output_root_mean_squared_error: 1.5797 - y2_output_root_mean_squared_error: 2.4353 - val_loss: 6.8228 - val_y1_output_loss: 2.0261 - val_y2_output_loss: 4.8724 - val_y1_output_root_mean_squared_error: 1.3949 - val_y2_output_root_mean_squared_error: 2.2084
# Epoch 67/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.7777 - y1_output_loss: 1.2005 - y2_output_loss: 3.6124 - y1_output_root_mean_squared_error: 1.0852 - y2_output_root_mean_squared_error: 1.8974 - val_loss: 10.6966 - val_y1_output_loss: 4.0283 - val_y2_output_loss: 7.0377 - val_y1_output_root_mean_squared_error: 1.9390 - val_y2_output_root_mean_squared_error: 2.6338
# Epoch 68/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.1379 - y1_output_loss: 1.1964 - y2_output_loss: 2.9296 - y1_output_root_mean_squared_error: 1.0950 - y2_output_root_mean_squared_error: 1.7143 - val_loss: 5.6116 - val_y1_output_loss: 1.0677 - val_y2_output_loss: 4.5577 - val_y1_output_root_mean_squared_error: 1.0098 - val_y2_output_root_mean_squared_error: 2.1429
# Epoch 69/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.0156 - y1_output_loss: 1.9622 - y2_output_loss: 5.0449 - y1_output_root_mean_squared_error: 1.4067 - y2_output_root_mean_squared_error: 2.2443 - val_loss: 16.4939 - val_y1_output_loss: 2.9377 - val_y2_output_loss: 14.2400 - val_y1_output_root_mean_squared_error: 1.7147 - val_y2_output_root_mean_squared_error: 3.6815
# Epoch 70/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.7940 - y1_output_loss: 1.2394 - y2_output_loss: 3.8725 - y1_output_root_mean_squared_error: 1.0575 - y2_output_root_mean_squared_error: 1.9172 - val_loss: 27.6683 - val_y1_output_loss: 9.7891 - val_y2_output_loss: 19.8187 - val_y1_output_root_mean_squared_error: 3.0345 - val_y2_output_root_mean_squared_error: 4.2965
# Epoch 71/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.0505 - y1_output_loss: 1.5439 - y2_output_loss: 4.5284 - y1_output_root_mean_squared_error: 1.2415 - y2_output_root_mean_squared_error: 2.1235 - val_loss: 6.8792 - val_y1_output_loss: 1.3729 - val_y2_output_loss: 5.7149 - val_y1_output_root_mean_squared_error: 1.1600 - val_y2_output_root_mean_squared_error: 2.3524
# Epoch 72/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.5875 - y1_output_loss: 0.9509 - y2_output_loss: 2.6370 - y1_output_root_mean_squared_error: 0.9791 - y2_output_root_mean_squared_error: 1.6214 - val_loss: 4.2758 - val_y1_output_loss: 0.7490 - val_y2_output_loss: 3.7072 - val_y1_output_root_mean_squared_error: 0.8698 - val_y2_output_root_mean_squared_error: 1.8760
# Epoch 73/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.6071 - y1_output_loss: 0.8809 - y2_output_loss: 2.7167 - y1_output_root_mean_squared_error: 0.9358 - y2_output_root_mean_squared_error: 1.6527 - val_loss: 5.0583 - val_y1_output_loss: 1.2323 - val_y2_output_loss: 3.9186 - val_y1_output_root_mean_squared_error: 1.0849 - val_y2_output_root_mean_squared_error: 1.9701
# Epoch 74/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.8090 - y1_output_loss: 0.9676 - y2_output_loss: 2.8284 - y1_output_root_mean_squared_error: 0.9808 - y2_output_root_mean_squared_error: 1.6873 - val_loss: 5.1738 - val_y1_output_loss: 1.3341 - val_y2_output_loss: 3.9337 - val_y1_output_root_mean_squared_error: 1.1479 - val_y2_output_root_mean_squared_error: 1.9637
# Epoch 75/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.5813 - y1_output_loss: 1.4914 - y2_output_loss: 4.0485 - y1_output_root_mean_squared_error: 1.2251 - y2_output_root_mean_squared_error: 2.0200 - val_loss: 4.3649 - val_y1_output_loss: 1.1443 - val_y2_output_loss: 3.3246 - val_y1_output_root_mean_squared_error: 1.0438 - val_y2_output_root_mean_squared_error: 1.8098
# Epoch 76/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.8345 - y1_output_loss: 0.9933 - y2_output_loss: 2.8203 - y1_output_root_mean_squared_error: 0.9976 - y2_output_root_mean_squared_error: 1.6850 - val_loss: 3.9678 - val_y1_output_loss: 0.8807 - val_y2_output_loss: 3.1816 - val_y1_output_root_mean_squared_error: 0.9520 - val_y2_output_root_mean_squared_error: 1.7497
# Epoch 77/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9469 - y1_output_loss: 1.0993 - y2_output_loss: 2.8529 - y1_output_root_mean_squared_error: 1.0444 - y2_output_root_mean_squared_error: 1.6900 - val_loss: 17.5161 - val_y1_output_loss: 5.6929 - val_y2_output_loss: 12.2524 - val_y1_output_root_mean_squared_error: 2.3297 - val_y2_output_root_mean_squared_error: 3.4768
# Epoch 78/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.6624 - y1_output_loss: 1.1344 - y2_output_loss: 3.5523 - y1_output_root_mean_squared_error: 1.0614 - y2_output_root_mean_squared_error: 1.8804 - val_loss: 25.3494 - val_y1_output_loss: 7.1339 - val_y2_output_loss: 18.6011 - val_y1_output_root_mean_squared_error: 2.6167 - val_y2_output_root_mean_squared_error: 4.3014
# Epoch 79/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.8266 - y1_output_loss: 1.6349 - y2_output_loss: 5.2110 - y1_output_root_mean_squared_error: 1.2834 - y2_output_root_mean_squared_error: 2.2758 - val_loss: 8.8098 - val_y1_output_loss: 1.5196 - val_y2_output_loss: 7.5207 - val_y1_output_root_mean_squared_error: 1.1722 - val_y2_output_root_mean_squared_error: 2.7269
# Epoch 80/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.9206 - y1_output_loss: 0.9660 - y2_output_loss: 2.9501 - y1_output_root_mean_squared_error: 0.9712 - y2_output_root_mean_squared_error: 1.7255 - val_loss: 7.6604 - val_y1_output_loss: 2.7770 - val_y2_output_loss: 5.0668 - val_y1_output_root_mean_squared_error: 1.6193 - val_y2_output_root_mean_squared_error: 2.2446
# Epoch 81/500
# 614/614 [==============================] - 0s 163us/sample - loss: 4.0688 - y1_output_loss: 1.0238 - y2_output_loss: 3.0138 - y1_output_root_mean_squared_error: 1.0165 - y2_output_root_mean_squared_error: 1.7423 - val_loss: 5.1005 - val_y1_output_loss: 1.3235 - val_y2_output_loss: 3.9284 - val_y1_output_root_mean_squared_error: 1.1478 - val_y2_output_root_mean_squared_error: 1.9450
# Epoch 82/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.2123 - y1_output_loss: 1.4074 - y2_output_loss: 3.7732 - y1_output_root_mean_squared_error: 1.1892 - y2_output_root_mean_squared_error: 1.9489 - val_loss: 3.5062 - val_y1_output_loss: 0.8045 - val_y2_output_loss: 2.7612 - val_y1_output_root_mean_squared_error: 0.8755 - val_y2_output_root_mean_squared_error: 1.6552
# Epoch 83/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.4046 - y1_output_loss: 0.8277 - y2_output_loss: 2.5569 - y1_output_root_mean_squared_error: 0.9123 - y2_output_root_mean_squared_error: 1.6038 - val_loss: 4.9492 - val_y1_output_loss: 1.3383 - val_y2_output_loss: 3.7815 - val_y1_output_root_mean_squared_error: 1.1144 - val_y2_output_root_mean_squared_error: 1.9254
# Epoch 84/500
# 614/614 [==============================] - 0s 175us/sample - loss: 3.7289 - y1_output_loss: 0.8862 - y2_output_loss: 2.8318 - y1_output_root_mean_squared_error: 0.9371 - y2_output_root_mean_squared_error: 1.6884 - val_loss: 4.3075 - val_y1_output_loss: 1.1260 - val_y2_output_loss: 3.2722 - val_y1_output_root_mean_squared_error: 1.0788 - val_y2_output_root_mean_squared_error: 1.7731
# Epoch 85/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.2873 - y1_output_loss: 1.4586 - y2_output_loss: 3.8385 - y1_output_root_mean_squared_error: 1.2124 - y2_output_root_mean_squared_error: 1.9538 - val_loss: 3.7245 - val_y1_output_loss: 0.7548 - val_y2_output_loss: 3.0112 - val_y1_output_root_mean_squared_error: 0.8744 - val_y2_output_root_mean_squared_error: 1.7204
# Epoch 86/500
# 614/614 [==============================] - 0s 175us/sample - loss: 3.4863 - y1_output_loss: 0.8403 - y2_output_loss: 2.7202 - y1_output_root_mean_squared_error: 0.9089 - y2_output_root_mean_squared_error: 1.6310 - val_loss: 13.2713 - val_y1_output_loss: 3.2822 - val_y2_output_loss: 10.0264 - val_y1_output_root_mean_squared_error: 1.7795 - val_y2_output_root_mean_squared_error: 3.1788
# Epoch 87/500
# 614/614 [==============================] - 0s 168us/sample - loss: 5.1216 - y1_output_loss: 1.2972 - y2_output_loss: 3.8476 - y1_output_root_mean_squared_error: 1.1410 - y2_output_root_mean_squared_error: 1.9544 - val_loss: 4.3250 - val_y1_output_loss: 1.1243 - val_y2_output_loss: 3.2379 - val_y1_output_root_mean_squared_error: 1.0253 - val_y2_output_root_mean_squared_error: 1.8093
# Epoch 88/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.4521 - y1_output_loss: 0.8828 - y2_output_loss: 2.5598 - y1_output_root_mean_squared_error: 0.9426 - y2_output_root_mean_squared_error: 1.6011 - val_loss: 3.8446 - val_y1_output_loss: 1.0519 - val_y2_output_loss: 2.9399 - val_y1_output_root_mean_squared_error: 1.0006 - val_y2_output_root_mean_squared_error: 1.6862
# Epoch 89/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.0172 - y1_output_loss: 0.8938 - y2_output_loss: 3.1133 - y1_output_root_mean_squared_error: 0.9498 - y2_output_root_mean_squared_error: 1.7650 - val_loss: 3.4325 - val_y1_output_loss: 0.6172 - val_y2_output_loss: 2.9683 - val_y1_output_root_mean_squared_error: 0.7686 - val_y2_output_root_mean_squared_error: 1.6857
# Epoch 90/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.7034 - y1_output_loss: 0.9031 - y2_output_loss: 2.7751 - y1_output_root_mean_squared_error: 0.9507 - y2_output_root_mean_squared_error: 1.6732 - val_loss: 3.1441 - val_y1_output_loss: 0.7038 - val_y2_output_loss: 2.5022 - val_y1_output_root_mean_squared_error: 0.8181 - val_y2_output_root_mean_squared_error: 1.5731
# Epoch 91/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.1791 - y1_output_loss: 0.7367 - y2_output_loss: 2.4146 - y1_output_root_mean_squared_error: 0.8618 - y2_output_root_mean_squared_error: 1.5609 - val_loss: 3.2193 - val_y1_output_loss: 0.7182 - val_y2_output_loss: 2.5260 - val_y1_output_root_mean_squared_error: 0.8528 - val_y2_output_root_mean_squared_error: 1.5786
# Epoch 92/500
# 614/614 [==============================] - 0s 167us/sample - loss: 6.1804 - y1_output_loss: 1.5463 - y2_output_loss: 4.5918 - y1_output_root_mean_squared_error: 1.2486 - y2_output_root_mean_squared_error: 2.1497 - val_loss: 10.0329 - val_y1_output_loss: 3.4410 - val_y2_output_loss: 6.9171 - val_y1_output_root_mean_squared_error: 1.7918 - val_y2_output_root_mean_squared_error: 2.6120
# Epoch 93/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.5281 - y1_output_loss: 0.9164 - y2_output_loss: 2.5835 - y1_output_root_mean_squared_error: 0.9611 - y2_output_root_mean_squared_error: 1.6138 - val_loss: 4.1192 - val_y1_output_loss: 0.8581 - val_y2_output_loss: 3.2751 - val_y1_output_root_mean_squared_error: 0.9079 - val_y2_output_root_mean_squared_error: 1.8152
# Epoch 94/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.4396 - y1_output_loss: 0.8183 - y2_output_loss: 2.5942 - y1_output_root_mean_squared_error: 0.9069 - y2_output_root_mean_squared_error: 1.6177 - val_loss: 3.3479 - val_y1_output_loss: 0.5746 - val_y2_output_loss: 2.8288 - val_y1_output_root_mean_squared_error: 0.7475 - val_y2_output_root_mean_squared_error: 1.6700
# Epoch 95/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.5042 - y1_output_loss: 0.5911 - y2_output_loss: 1.8992 - y1_output_root_mean_squared_error: 0.7718 - y2_output_root_mean_squared_error: 1.3815 - val_loss: 3.9418 - val_y1_output_loss: 0.6705 - val_y2_output_loss: 3.3189 - val_y1_output_root_mean_squared_error: 0.7956 - val_y2_output_root_mean_squared_error: 1.8190
# Epoch 96/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.2281 - y1_output_loss: 0.8398 - y2_output_loss: 2.3598 - y1_output_root_mean_squared_error: 0.9197 - y2_output_root_mean_squared_error: 1.5435 - val_loss: 2.9541 - val_y1_output_loss: 0.6912 - val_y2_output_loss: 2.3865 - val_y1_output_root_mean_squared_error: 0.7997 - val_y2_output_root_mean_squared_error: 1.5214
# Epoch 97/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.6121 - y1_output_loss: 0.5773 - y2_output_loss: 2.0163 - y1_output_root_mean_squared_error: 0.7627 - y2_output_root_mean_squared_error: 1.4249 - val_loss: 4.6917 - val_y1_output_loss: 1.5834 - val_y2_output_loss: 3.3339 - val_y1_output_root_mean_squared_error: 1.2038 - val_y2_output_root_mean_squared_error: 1.8007
# Epoch 98/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.0219 - y1_output_loss: 0.8356 - y2_output_loss: 3.2192 - y1_output_root_mean_squared_error: 0.9148 - y2_output_root_mean_squared_error: 1.7847 - val_loss: 4.3067 - val_y1_output_loss: 0.7205 - val_y2_output_loss: 3.8236 - val_y1_output_root_mean_squared_error: 0.8468 - val_y2_output_root_mean_squared_error: 1.8946
# Epoch 99/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.2044 - y1_output_loss: 0.7391 - y2_output_loss: 2.4792 - y1_output_root_mean_squared_error: 0.8635 - y2_output_root_mean_squared_error: 1.5681 - val_loss: 3.7371 - val_y1_output_loss: 0.7923 - val_y2_output_loss: 3.0422 - val_y1_output_root_mean_squared_error: 0.8974 - val_y2_output_root_mean_squared_error: 1.7122
# Epoch 100/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.8706 - y1_output_loss: 0.9041 - y2_output_loss: 2.9652 - y1_output_root_mean_squared_error: 0.9453 - y2_output_root_mean_squared_error: 1.7254 - val_loss: 6.6905 - val_y1_output_loss: 2.2480 - val_y2_output_loss: 4.6806 - val_y1_output_root_mean_squared_error: 1.4612 - val_y2_output_root_mean_squared_error: 2.1343
# Epoch 101/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.6196 - y1_output_loss: 0.8412 - y2_output_loss: 2.7473 - y1_output_root_mean_squared_error: 0.9215 - y2_output_root_mean_squared_error: 1.6645 - val_loss: 3.4110 - val_y1_output_loss: 0.8155 - val_y2_output_loss: 2.6792 - val_y1_output_root_mean_squared_error: 0.9008 - val_y2_output_root_mean_squared_error: 1.6123
# Epoch 102/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.5744 - y1_output_loss: 0.6272 - y2_output_loss: 1.9412 - y1_output_root_mean_squared_error: 0.7949 - y2_output_root_mean_squared_error: 1.3938 - val_loss: 8.7047 - val_y1_output_loss: 1.4075 - val_y2_output_loss: 7.4121 - val_y1_output_root_mean_squared_error: 1.1473 - val_y2_output_root_mean_squared_error: 2.7182
# Epoch 103/500
# 614/614 [==============================] - 0s 161us/sample - loss: 4.6837 - y1_output_loss: 1.1530 - y2_output_loss: 3.5159 - y1_output_root_mean_squared_error: 1.0778 - y2_output_root_mean_squared_error: 1.8767 - val_loss: 7.5165 - val_y1_output_loss: 1.1249 - val_y2_output_loss: 6.4740 - val_y1_output_root_mean_squared_error: 1.0243 - val_y2_output_root_mean_squared_error: 2.5431
# Epoch 104/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.3716 - y1_output_loss: 0.7036 - y2_output_loss: 1.7029 - y1_output_root_mean_squared_error: 0.8296 - y2_output_root_mean_squared_error: 1.2974 - val_loss: 3.3596 - val_y1_output_loss: 0.8728 - val_y2_output_loss: 2.5442 - val_y1_output_root_mean_squared_error: 0.9235 - val_y2_output_root_mean_squared_error: 1.5833
# Epoch 105/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.6032 - y1_output_loss: 0.5978 - y2_output_loss: 1.9871 - y1_output_root_mean_squared_error: 0.7756 - y2_output_root_mean_squared_error: 1.4148 - val_loss: 3.8471 - val_y1_output_loss: 0.5789 - val_y2_output_loss: 3.2937 - val_y1_output_root_mean_squared_error: 0.7329 - val_y2_output_root_mean_squared_error: 1.8193
# Epoch 106/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.5505 - y1_output_loss: 0.5682 - y2_output_loss: 1.9600 - y1_output_root_mean_squared_error: 0.7561 - y2_output_root_mean_squared_error: 1.4067 - val_loss: 2.7907 - val_y1_output_loss: 0.4029 - val_y2_output_loss: 2.4581 - val_y1_output_root_mean_squared_error: 0.6229 - val_y2_output_root_mean_squared_error: 1.5501
# Epoch 107/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.9297 - y1_output_loss: 0.7289 - y2_output_loss: 2.1960 - y1_output_root_mean_squared_error: 0.8563 - y2_output_root_mean_squared_error: 1.4820 - val_loss: 7.3644 - val_y1_output_loss: 0.7746 - val_y2_output_loss: 6.7072 - val_y1_output_root_mean_squared_error: 0.8414 - val_y2_output_root_mean_squared_error: 2.5800
# Epoch 108/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.1969 - y1_output_loss: 0.4987 - y2_output_loss: 1.6906 - y1_output_root_mean_squared_error: 0.7060 - y2_output_root_mean_squared_error: 1.3032 - val_loss: 4.3134 - val_y1_output_loss: 0.5407 - val_y2_output_loss: 3.7968 - val_y1_output_root_mean_squared_error: 0.7173 - val_y2_output_root_mean_squared_error: 1.9491
# Epoch 109/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.4982 - y1_output_loss: 0.5715 - y2_output_loss: 1.9095 - y1_output_root_mean_squared_error: 0.7589 - y2_output_root_mean_squared_error: 1.3865 - val_loss: 2.7389 - val_y1_output_loss: 0.4841 - val_y2_output_loss: 2.3577 - val_y1_output_root_mean_squared_error: 0.6978 - val_y2_output_root_mean_squared_error: 1.5007
# Epoch 110/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.5371 - y1_output_loss: 0.6115 - y2_output_loss: 1.9077 - y1_output_root_mean_squared_error: 0.7839 - y2_output_root_mean_squared_error: 1.3866 - val_loss: 2.6046 - val_y1_output_loss: 0.5201 - val_y2_output_loss: 2.2241 - val_y1_output_root_mean_squared_error: 0.6978 - val_y2_output_root_mean_squared_error: 1.4552
# Epoch 111/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.0753 - y1_output_loss: 0.6835 - y2_output_loss: 2.3719 - y1_output_root_mean_squared_error: 0.8286 - y2_output_root_mean_squared_error: 1.5455 - val_loss: 2.5820 - val_y1_output_loss: 0.5394 - val_y2_output_loss: 2.1264 - val_y1_output_root_mean_squared_error: 0.7169 - val_y2_output_root_mean_squared_error: 1.4381
# Epoch 112/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.1653 - y1_output_loss: 0.8065 - y2_output_loss: 2.3373 - y1_output_root_mean_squared_error: 0.9022 - y2_output_root_mean_squared_error: 1.5334 - val_loss: 3.1024 - val_y1_output_loss: 0.8661 - val_y2_output_loss: 2.2882 - val_y1_output_root_mean_squared_error: 0.9225 - val_y2_output_root_mean_squared_error: 1.5005
# Epoch 113/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.9760 - y1_output_loss: 0.6980 - y2_output_loss: 2.2513 - y1_output_root_mean_squared_error: 0.8391 - y2_output_root_mean_squared_error: 1.5073 - val_loss: 3.0967 - val_y1_output_loss: 0.6545 - val_y2_output_loss: 2.5373 - val_y1_output_root_mean_squared_error: 0.7664 - val_y2_output_root_mean_squared_error: 1.5841
# Epoch 114/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.1752 - y1_output_loss: 0.5096 - y2_output_loss: 1.6774 - y1_output_root_mean_squared_error: 0.7161 - y2_output_root_mean_squared_error: 1.2894 - val_loss: 4.5730 - val_y1_output_loss: 1.2726 - val_y2_output_loss: 3.3795 - val_y1_output_root_mean_squared_error: 1.1067 - val_y2_output_root_mean_squared_error: 1.8298
# Epoch 115/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.2655 - y1_output_loss: 0.5766 - y2_output_loss: 1.6874 - y1_output_root_mean_squared_error: 0.7608 - y2_output_root_mean_squared_error: 1.2987 - val_loss: 2.6519 - val_y1_output_loss: 0.4633 - val_y2_output_loss: 2.2508 - val_y1_output_root_mean_squared_error: 0.6792 - val_y2_output_root_mean_squared_error: 1.4800
# Epoch 116/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.7502 - y1_output_loss: 0.4950 - y2_output_loss: 2.2520 - y1_output_root_mean_squared_error: 0.7030 - y2_output_root_mean_squared_error: 1.5020 - val_loss: 2.5211 - val_y1_output_loss: 0.6511 - val_y2_output_loss: 1.8969 - val_y1_output_root_mean_squared_error: 0.8098 - val_y2_output_root_mean_squared_error: 1.3658
# Epoch 117/500
# 614/614 [==============================] - 0s 172us/sample - loss: 1.8513 - y1_output_loss: 0.4603 - y2_output_loss: 1.3902 - y1_output_root_mean_squared_error: 0.6784 - y2_output_root_mean_squared_error: 1.1795 - val_loss: 4.4342 - val_y1_output_loss: 1.2110 - val_y2_output_loss: 3.3887 - val_y1_output_root_mean_squared_error: 1.0703 - val_y2_output_root_mean_squared_error: 1.8135
# Epoch 118/500
# 614/614 [==============================] - 0s 163us/sample - loss: 1.9858 - y1_output_loss: 0.5223 - y2_output_loss: 1.4612 - y1_output_root_mean_squared_error: 0.7249 - y2_output_root_mean_squared_error: 1.2084 - val_loss: 3.8183 - val_y1_output_loss: 0.7093 - val_y2_output_loss: 3.1969 - val_y1_output_root_mean_squared_error: 0.8223 - val_y2_output_root_mean_squared_error: 1.7726
# Epoch 119/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.4468 - y1_output_loss: 0.5860 - y2_output_loss: 1.8417 - y1_output_root_mean_squared_error: 0.7668 - y2_output_root_mean_squared_error: 1.3634 - val_loss: 2.7526 - val_y1_output_loss: 0.5327 - val_y2_output_loss: 2.3183 - val_y1_output_root_mean_squared_error: 0.7187 - val_y2_output_root_mean_squared_error: 1.4953
# Epoch 120/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.9423 - y1_output_loss: 0.9036 - y2_output_loss: 3.0176 - y1_output_root_mean_squared_error: 0.9494 - y2_output_root_mean_squared_error: 1.7438 - val_loss: 3.0411 - val_y1_output_loss: 0.6527 - val_y2_output_loss: 2.4933 - val_y1_output_root_mean_squared_error: 0.8116 - val_y2_output_root_mean_squared_error: 1.5435
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4305 - y1_output_loss: 0.1244 - y2_output_loss: 0.3040 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 0.7568 - val_y1_output_loss: 0.2102 - val_y2_output_loss: 0.5317 - val_y1_output_root_mean_squared_error: 0.4646 - val_y2_output_root_mean_squared_error: 0.7355
# Epoch 462/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3995 - y1_output_loss: 0.1253 - y2_output_loss: 0.2710 - y1_output_root_mean_squared_error: 0.3553 - y2_output_root_mean_squared_error: 0.5227 - val_loss: 0.7821 - val_y1_output_loss: 0.2032 - val_y2_output_loss: 0.5634 - val_y1_output_root_mean_squared_error: 0.4534 - val_y2_output_root_mean_squared_error: 0.7592
# Epoch 463/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.4472 - y1_output_loss: 0.1302 - y2_output_loss: 0.3156 - y1_output_root_mean_squared_error: 0.3601 - y2_output_root_mean_squared_error: 0.5635 - val_loss: 0.7809 - val_y1_output_loss: 0.2079 - val_y2_output_loss: 0.5595 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.7529
# Epoch 464/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.4379 - y1_output_loss: 0.1284 - y2_output_loss: 0.3071 - y1_output_root_mean_squared_error: 0.3577 - y2_output_root_mean_squared_error: 0.5567 - val_loss: 0.7923 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.5399 - val_y1_output_root_mean_squared_error: 0.4928 - val_y2_output_root_mean_squared_error: 0.7412
# Epoch 465/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4057 - y1_output_loss: 0.1146 - y2_output_loss: 0.2970 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.5390 - val_loss: 1.5354 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 1.2825 - val_y1_output_root_mean_squared_error: 0.4910 - val_y2_output_root_mean_squared_error: 1.1377
# Epoch 466/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4279 - y1_output_loss: 0.1280 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3587 - y2_output_root_mean_squared_error: 0.5470 - val_loss: 0.9994 - val_y1_output_loss: 0.2545 - val_y2_output_loss: 0.7270 - val_y1_output_root_mean_squared_error: 0.5124 - val_y2_output_root_mean_squared_error: 0.8584
# Epoch 467/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4397 - y1_output_loss: 0.1242 - y2_output_loss: 0.3133 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5614 - val_loss: 0.8452 - val_y1_output_loss: 0.2581 - val_y2_output_loss: 0.5725 - val_y1_output_root_mean_squared_error: 0.5150 - val_y2_output_root_mean_squared_error: 0.7615
# Epoch 468/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3151 - y1_output_loss: 0.1095 - y2_output_loss: 0.2040 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.4536 - val_loss: 0.7617 - val_y1_output_loss: 0.2516 - val_y2_output_loss: 0.5096 - val_y1_output_root_mean_squared_error: 0.4957 - val_y2_output_root_mean_squared_error: 0.7183
# Epoch 469/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4038 - y1_output_loss: 0.1107 - y2_output_loss: 0.2923 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.5407 - val_loss: 0.7740 - val_y1_output_loss: 0.2113 - val_y2_output_loss: 0.5516 - val_y1_output_root_mean_squared_error: 0.4638 - val_y2_output_root_mean_squared_error: 0.7476
# Epoch 470/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.3486 - y1_output_loss: 0.1070 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3276 - y2_output_root_mean_squared_error: 0.4912 - val_loss: 0.7959 - val_y1_output_loss: 0.2186 - val_y2_output_loss: 0.5691 - val_y1_output_root_mean_squared_error: 0.4692 - val_y2_output_root_mean_squared_error: 0.7587
# Epoch 471/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.7458 - y1_output_loss: 0.2210 - y2_output_loss: 0.5199 - y1_output_root_mean_squared_error: 0.4707 - y2_output_root_mean_squared_error: 0.7241 - val_loss: 1.0064 - val_y1_output_loss: 0.2811 - val_y2_output_loss: 0.7169 - val_y1_output_root_mean_squared_error: 0.5389 - val_y2_output_root_mean_squared_error: 0.8462
# Epoch 472/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.8701 - y1_output_loss: 0.1964 - y2_output_loss: 0.6670 - y1_output_root_mean_squared_error: 0.4450 - y2_output_root_mean_squared_error: 0.8198 - val_loss: 0.8210 - val_y1_output_loss: 0.2201 - val_y2_output_loss: 0.5859 - val_y1_output_root_mean_squared_error: 0.4738 - val_y2_output_root_mean_squared_error: 0.7724
# Epoch 473/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4273 - y1_output_loss: 0.1346 - y2_output_loss: 0.2899 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5400 - val_loss: 1.0883 - val_y1_output_loss: 0.2055 - val_y2_output_loss: 0.8723 - val_y1_output_root_mean_squared_error: 0.4566 - val_y2_output_root_mean_squared_error: 0.9379
# Epoch 474/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.4340 - y1_output_loss: 0.1189 - y2_output_loss: 0.3195 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.5604 - val_loss: 1.6191 - val_y1_output_loss: 0.2184 - val_y2_output_loss: 1.4039 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 1.1808
# Epoch 475/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.4127 - y1_output_loss: 0.1216 - y2_output_loss: 0.2901 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.5403 - val_loss: 0.8521 - val_y1_output_loss: 0.2587 - val_y2_output_loss: 0.5796 - val_y1_output_root_mean_squared_error: 0.5124 - val_y2_output_root_mean_squared_error: 0.7679
# Epoch 476/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4141 - y1_output_loss: 0.1147 - y2_output_loss: 0.2967 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 0.8431 - val_y1_output_loss: 0.2777 - val_y2_output_loss: 0.5472 - val_y1_output_root_mean_squared_error: 0.5341 - val_y2_output_root_mean_squared_error: 0.7469
# Epoch 477/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4902 - y1_output_loss: 0.1212 - y2_output_loss: 0.3683 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.6067 - val_loss: 1.1877 - val_y1_output_loss: 0.2583 - val_y2_output_loss: 0.9262 - val_y1_output_root_mean_squared_error: 0.5042 - val_y2_output_root_mean_squared_error: 0.9661
# Epoch 478/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4276 - y1_output_loss: 0.1281 - y2_output_loss: 0.2982 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5481 - val_loss: 0.8832 - val_y1_output_loss: 0.2685 - val_y2_output_loss: 0.6122 - val_y1_output_root_mean_squared_error: 0.5142 - val_y2_output_root_mean_squared_error: 0.7866
# Epoch 479/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4126 - y1_output_loss: 0.1220 - y2_output_loss: 0.2886 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 0.8125 - val_y1_output_loss: 0.2288 - val_y2_output_loss: 0.5696 - val_y1_output_root_mean_squared_error: 0.4838 - val_y2_output_root_mean_squared_error: 0.7605
# Epoch 480/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.3486 - y1_output_loss: 0.1087 - y2_output_loss: 0.2381 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.4899 - val_loss: 0.8294 - val_y1_output_loss: 0.2446 - val_y2_output_loss: 0.5838 - val_y1_output_root_mean_squared_error: 0.4979 - val_y2_output_root_mean_squared_error: 0.7625
# Epoch 481/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3488 - y1_output_loss: 0.1036 - y2_output_loss: 0.2428 - y1_output_root_mean_squared_error: 0.3231 - y2_output_root_mean_squared_error: 0.4944 - val_loss: 1.0028 - val_y1_output_loss: 0.1929 - val_y2_output_loss: 0.8015 - val_y1_output_root_mean_squared_error: 0.4437 - val_y2_output_root_mean_squared_error: 0.8977
# Epoch 482/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3889 - y1_output_loss: 0.1089 - y2_output_loss: 0.2774 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.5287 - val_loss: 1.0217 - val_y1_output_loss: 0.2826 - val_y2_output_loss: 0.7408 - val_y1_output_root_mean_squared_error: 0.5263 - val_y2_output_root_mean_squared_error: 0.8630
# Epoch 483/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4975 - y1_output_loss: 0.1326 - y2_output_loss: 0.3618 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.6034 - val_loss: 0.7502 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.5288 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 484/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3603 - y1_output_loss: 0.1142 - y2_output_loss: 0.2441 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.4959 - val_loss: 0.8762 - val_y1_output_loss: 0.2457 - val_y2_output_loss: 0.6151 - val_y1_output_root_mean_squared_error: 0.5021 - val_y2_output_root_mean_squared_error: 0.7900
# Epoch 485/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.3468 - y1_output_loss: 0.1053 - y2_output_loss: 0.2414 - y1_output_root_mean_squared_error: 0.3252 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 0.8567 - val_y1_output_loss: 0.1962 - val_y2_output_loss: 0.6494 - val_y1_output_root_mean_squared_error: 0.4501 - val_y2_output_root_mean_squared_error: 0.8088
# Epoch 486/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3210 - y1_output_loss: 0.0974 - y2_output_loss: 0.2234 - y1_output_root_mean_squared_error: 0.3132 - y2_output_root_mean_squared_error: 0.4721 - val_loss: 0.7190 - val_y1_output_loss: 0.1840 - val_y2_output_loss: 0.5238 - val_y1_output_root_mean_squared_error: 0.4310 - val_y2_output_root_mean_squared_error: 0.7303
# Epoch 487/500
# 614/614 [==============================] - 0s 192us/sample - loss: 0.4424 - y1_output_loss: 0.1275 - y2_output_loss: 0.3114 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 0.7993 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.5922 - val_y1_output_root_mean_squared_error: 0.4480 - val_y2_output_root_mean_squared_error: 0.7737
# Epoch 488/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3511 - y1_output_loss: 0.1176 - y2_output_loss: 0.2361 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.4855 - val_loss: 0.9047 - val_y1_output_loss: 0.2035 - val_y2_output_loss: 0.6838 - val_y1_output_root_mean_squared_error: 0.4577 - val_y2_output_root_mean_squared_error: 0.8338
# Epoch 489/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3473 - y1_output_loss: 0.1092 - y2_output_loss: 0.2379 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.4886 - val_loss: 0.9769 - val_y1_output_loss: 0.2628 - val_y2_output_loss: 0.7044 - val_y1_output_root_mean_squared_error: 0.5119 - val_y2_output_root_mean_squared_error: 0.8455
# Epoch 490/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.5195 - y1_output_loss: 0.1383 - y2_output_loss: 0.3770 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.6163 - val_loss: 0.8650 - val_y1_output_loss: 0.2189 - val_y2_output_loss: 0.6380 - val_y1_output_root_mean_squared_error: 0.4694 - val_y2_output_root_mean_squared_error: 0.8029
# Epoch 491/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3277 - y1_output_loss: 0.0980 - y2_output_loss: 0.2333 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4788 - val_loss: 1.6216 - val_y1_output_loss: 0.3004 - val_y2_output_loss: 1.3265 - val_y1_output_root_mean_squared_error: 0.5457 - val_y2_output_root_mean_squared_error: 1.1506
# Epoch 492/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3812 - y1_output_loss: 0.1071 - y2_output_loss: 0.2721 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.5240 - val_loss: 0.8433 - val_y1_output_loss: 0.2949 - val_y2_output_loss: 0.5500 - val_y1_output_root_mean_squared_error: 0.5338 - val_y2_output_root_mean_squared_error: 0.7472
# Epoch 493/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3460 - y1_output_loss: 0.1127 - y2_output_loss: 0.2311 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.4822 - val_loss: 0.7462 - val_y1_output_loss: 0.2004 - val_y2_output_loss: 0.5293 - val_y1_output_root_mean_squared_error: 0.4519 - val_y2_output_root_mean_squared_error: 0.7362
# Epoch 494/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3194 - y1_output_loss: 0.0948 - y2_output_loss: 0.2226 - y1_output_root_mean_squared_error: 0.3090 - y2_output_root_mean_squared_error: 0.4731 - val_loss: 0.7883 - val_y1_output_loss: 0.2263 - val_y2_output_loss: 0.5441 - val_y1_output_root_mean_squared_error: 0.4838 - val_y2_output_root_mean_squared_error: 0.7445
# Epoch 495/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.5182 - y1_output_loss: 0.1294 - y2_output_loss: 0.3956 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.6262 - val_loss: 2.3345 - val_y1_output_loss: 0.6508 - val_y2_output_loss: 1.6715 - val_y1_output_root_mean_squared_error: 0.8131 - val_y2_output_root_mean_squared_error: 1.2936
# Epoch 496/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.6179 - y1_output_loss: 0.1711 - y2_output_loss: 0.4427 - y1_output_root_mean_squared_error: 0.4144 - y2_output_root_mean_squared_error: 0.6679 - val_loss: 0.7121 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.5027 - val_y1_output_root_mean_squared_error: 0.4510 - val_y2_output_root_mean_squared_error: 0.7133
# Epoch 497/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3629 - y1_output_loss: 0.1056 - y2_output_loss: 0.2775 - y1_output_root_mean_squared_error: 0.3218 - y2_output_root_mean_squared_error: 0.5093 - val_loss: 6.6045 - val_y1_output_loss: 0.8864 - val_y2_output_loss: 5.7221 - val_y1_output_root_mean_squared_error: 0.9468 - val_y2_output_root_mean_squared_error: 2.3892
# Epoch 498/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.6045 - y1_output_loss: 0.1438 - y2_output_loss: 0.4561 - y1_output_root_mean_squared_error: 0.3803 - y2_output_root_mean_squared_error: 0.6781 - val_loss: 0.6853 - val_y1_output_loss: 0.1857 - val_y2_output_loss: 0.4881 - val_y1_output_root_mean_squared_error: 0.4325 - val_y2_output_root_mean_squared_error: 0.7059
# Epoch 499/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3352 - y1_output_loss: 0.1065 - y2_output_loss: 0.2298 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4779 - val_loss: 0.8436 - val_y1_output_loss: 0.2169 - val_y2_output_loss: 0.6142 - val_y1_output_root_mean_squared_error: 0.4722 - val_y2_output_root_mean_squared_error: 0.7878
# Epoch 500/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3765 - y1_output_loss: 0.1073 - y2_output_loss: 0.2692 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.5198 - val_loss: 0.7487 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.5392 - val_y1_output_root_mean_squared_error: 0.4469 - val_y2_output_root_mean_squared_error: 0.7409

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 65us/sample - loss: 0.7487 - y1_output_loss: 0.1975 - y2_output_loss: 0.5621 - y1_output_root_mean_squared_error: 0.4469 - y2_output_root_mean_squared_error: 0.7409
# Loss = 0.7487074709557867, Y1_loss = 0.197494238615036, Y1_mse = 0.4469096064567566, Y2_loss = 0.5620908141136169, Y2_mse = 0.7409313917160034

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
