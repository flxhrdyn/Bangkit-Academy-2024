# %% [markdown]
# # Ungraded Lab: First Autoencoder
#
# In this lab, you will build your first simple autoencoder. This will take in three-dimensional data, encodes it to two dimensions, and decodes it back to 3D.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Prepare and preview the dataset
#
# You will first create a synthetic dataset to act as input to the autoencoder. You can do that with the function below.

# %%
def generate_data(m):
    '''plots m random points on a 3D plane'''

    angles = np.random.rand(m) * 3 * np.pi / 2 - 0.5
    data = np.empty((m, 3))
    data[:,0] = np.cos(angles) + np.sin(angles)/2 + 0.1 * np.random.randn(m)/2
    data[:,1] = np.sin(angles) * 0.7 + 0.1 * np.random.randn(m) / 2
    data[:,2] = data[:, 0] * 0.1 + data[:, 1] * 0.3 + 0.1 * np.random.randn(m)

    return data

# %%
# use the function above to generate data points
X_train = generate_data(100)
X_train = X_train - X_train.mean(axis=0, keepdims=0)

# preview the data
ax = plt.axes(projection='3d')
ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap='Reds');
# Out:
# <ipython-input-3-42bc7d7259f7>:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter3D(X_train[:, 0], X_train[:, 1], X_train[:, 2], cmap='Reds');

# %% [markdown]
# ## Build the Model

# %% [markdown]
# Now you will build the simple encoder-decoder model. Notice the number of neurons in each Dense layer. The model will contract in the encoder then expand in the decoder.

# %%
encoder = keras.models.Sequential([keras.layers.Dense(2, input_shape=[3])])
decoder = keras.models.Sequential([keras.layers.Dense(3, input_shape=[2])])

autoencoder = keras.models.Sequential([encoder, decoder])

# %% [markdown]
# ## Compile the Model

# %% [markdown]
# You can then setup the model for training.

# %%
autoencoder.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=0.1))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %% [markdown]
# ## Train the Model

# %% [markdown]
# You will configure the training to also use the input data as your target output. In our example, that will be `X_train`.

# %%
history = autoencoder.fit(X_train, X_train, epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 15ms/step - loss: 0.5988
# Epoch 2/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5840
# Epoch 3/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5686
# Epoch 4/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5546
# Epoch 5/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5438
# Epoch 6/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5337
# Epoch 7/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5230
# Epoch 8/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5134
# Epoch 9/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5049
# Epoch 10/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4964
# Epoch 11/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4871
# Epoch 12/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4793
# Epoch 13/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4715
# Epoch 14/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4624
# Epoch 15/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4537
# Epoch 16/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4468
# Epoch 17/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4386
# Epoch 18/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4312
# Epoch 19/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4248
# Epoch 20/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4184
# Epoch 21/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4117
# Epoch 22/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4044
# Epoch 23/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3973
# Epoch 24/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3910
# Epoch 25/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3848
# Epoch 26/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3785
# Epoch 27/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3721
# Epoch 28/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3660
# Epoch 29/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3593
# Epoch 30/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3528
# Epoch 31/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3462
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3405
# Epoch 33/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3348
# Epoch 34/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3289
# Epoch 35/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3227
# Epoch 36/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0608
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0604
# Epoch 149/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0601
# Epoch 150/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0597
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0593
# Epoch 152/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0590
# Epoch 153/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0587
# Epoch 154/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0584
# Epoch 155/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0581
# Epoch 156/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0578
# Epoch 157/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0575
# Epoch 158/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0572
# Epoch 159/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0569
# Epoch 160/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0566
# Epoch 161/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0563
# Epoch 162/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0560
# Epoch 163/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0558
# Epoch 164/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0555
# Epoch 165/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0552
# Epoch 166/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0550
# Epoch 167/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0547
# Epoch 168/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0544
# Epoch 169/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0542
# Epoch 170/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0539
# Epoch 171/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0537
# Epoch 172/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0534
# Epoch 173/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0532
# Epoch 174/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0529
# Epoch 175/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0527
# Epoch 176/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0525
# Epoch 177/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0522
# Epoch 178/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0520
# Epoch 179/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0518
# Epoch 180/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0515
# Epoch 181/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0513
# Epoch 182/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0511
# Epoch 183/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0509
# Epoch 184/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0507
# Epoch 185/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0505
# Epoch 186/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0503
# Epoch 187/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0500
# Epoch 188/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0498
# Epoch 189/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0496
# Epoch 190/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0494
# Epoch 191/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0492
# Epoch 192/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0490
# Epoch 193/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0488
# Epoch 194/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0486
# Epoch 195/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0484
# Epoch 196/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0481
# Epoch 197/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0479
# Epoch 198/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0477
# Epoch 199/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0476
# Epoch 200/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0473

# %% [markdown]
# ## Plot the encoder output

# %% [markdown]
# As mentioned, you can use the encoder to compress the input to two dimensions.

# %%
# encode the data
codings = encoder.predict(X_train)

# see a sample input-encoder output pair
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
# Out:
# 4/4 [==============================] - 0s 3ms/step
# input point: [-1.07175112 -0.26126405 -0.34040533]
# encoded point: [-1.0886763 -0.4186619]

# %%
# plot all encoder outputs
fig = plt.figure(figsize=(4,3))
plt.plot(codings[:,0], codings[:, 1], "b.")
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18, rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Decoder output

# %% [markdown]
# The decoder then tries to reconstruct the original input. See the outputs below. You will see that although not perfect, it still follows the general shape of the original input.

# %%
# decode the encoder output
decodings = decoder.predict(codings)

# see a sample output for a single point
print(f'input point: {X_train[0]}')
print(f'encoded point: {codings[0]}')
print(f'decoded point: {decodings[0]}')
# Out:
# 4/4 [==============================] - 0s 2ms/step
# input point: [-1.07175112 -0.26126405 -0.34040533]
# encoded point: [-1.0886763 -0.4186619]
# decoded point: [-1.072356   -0.26649293 -0.2284181 ]

# %%
# plot the decoder output
ax = plt.axes(projection='3d')
ax.scatter3D(decodings[:, 0], decodings[:, 1], decodings[:, 2], c=decodings[:, 0], cmap='Reds');

# %% [markdown]
# That's it for this simple demonstration of the autoencoder!
